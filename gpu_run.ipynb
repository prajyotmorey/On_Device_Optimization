# %%
import torch

# %%
print("CUDA is available:", torch.cuda.is_available())
# Out:
# CUDA is available: True

# %%
# !python train_teacher.py
# Out:
# python3: can't open file '/content/train_teacher.py': [Errno 2] No such file or directory

# %%
# %%writefile train.py
# Out:
# Writing train.py

# %%
# !python train_teacher.py
# Out:
# python3: can't open file '/content/train_teacher.py': [Errno 2] No such file or directory
